# %% [markdown]
# ## Data transformation
#
# Modifying the datasets in a way that is easier to work with.

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
df_title_basics = pd.read_csv("data/title_basics.tsv", sep='\t', low_memory=False)
df_title_basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10295872  tt9916848  tvEpisode              Episode #3.17
# 10295873  tt9916850  tvEpisode              Episode #3.19
# 10295874  tt9916852  tvEpisode              Episode #3.20
# 10295875  tt9916856      short                   The Wind
# 10295876  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 10295872              Episode #3.17       0      2009      \N             \N
# 10295873              Episode #3.19       0      2010      \N             \N
# 10295874              Episode #3.20       0      2010      \N             \N
# 10295875                   The Wind       0      2015      \N             27
# 10295876  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10295872         Action,Drama,Family
# 10295873         Action,Drama,Family
# 10295874         Action,Drama,Family
# 10295875                       Short
# 10295876  Adventure,Animation,Comedy
#
# [10295877 rows x 9 columns]

# %%
title_types = df_title_basics["titleType"].unique()
title_types
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvSeries', 'tvEpisode',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
df_title_basics = df_title_basics[df_title_basics["titleType"].isin(["tvSeries", "tvEpisode"])]
df_title_basics
# Out:
#              tconst  titleType                 primaryTitle  \
# 34973     tt0035599   tvSeries  Voice of Firestone Televues
# 35174     tt0035803   tvSeries     The German Weekly Review
# 37603     tt0038276   tvSeries            You Are an Artist
# 38437     tt0039120   tvSeries                    Americana
# 38438     tt0039121   tvSeries               Birthday Party
# ...             ...        ...                          ...
# 10295871  tt9916846  tvEpisode                Episode #3.18
# 10295872  tt9916848  tvEpisode                Episode #3.17
# 10295873  tt9916850  tvEpisode                Episode #3.19
# 10295874  tt9916852  tvEpisode                Episode #3.20
# 10295876  tt9916880  tvEpisode    Horrid Henry Knows It All
#
#                         originalTitle isAdult startYear endYear  \
# 34973     Voice of Firestone Televues       0      1943    1947
# 35174        Die Deutsche Wochenschau       0      1940    1945
# 37603               You Are an Artist       0      1946    1955
# 38437                       Americana       0      1947    1949
# 38438                  Birthday Party       0      1947    1949
# ...                               ...     ...       ...     ...
# 10295871                Episode #3.18       0      2009      \N
# 10295872                Episode #3.17       0      2009      \N
# 10295873                Episode #3.19       0      2010      \N
# 10295874                Episode #3.20       0      2010      \N
# 10295876    Horrid Henry Knows It All       0      2014      \N
#
#          runtimeMinutes                      genres
# 34973                15                          \N
# 35174                12            Documentary,News
# 37603                15                   Talk-Show
# 38437                30            Family,Game-Show
# 38438                30                      Family
# ...                 ...                         ...
# 10295871             \N         Action,Drama,Family
# 10295872             \N         Action,Drama,Family
# 10295873             \N         Action,Drama,Family
# 10295874             \N         Action,Drama,Family
# 10295876             10  Adventure,Animation,Comedy
#
# [8105446 rows x 9 columns]

# %%
df_title_ratings = pd.read_csv("data/title_ratings.tsv", sep='\t', low_memory=False)
df_title_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2005
# 1        tt0000002            5.8       269
# 2        tt0000003            6.5      1908
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2688
# ...            ...            ...       ...
# 1366964  tt9916730            7.6        11
# 1366965  tt9916766            7.0        22
# 1366966  tt9916778            7.2        36
# 1366967  tt9916840            8.8         6
# 1366968  tt9916880            8.2         6
#
# [1366969 rows x 3 columns]

# %%
df_title_ratings = df_title_ratings[df_title_ratings["tconst"].isin(df_title_basics['tconst'])]
df_title_ratings
# Out:
#             tconst  averageRating  numVotes
# 18285    tt0035803            8.2        58
# 21018    tt0039120            2.7        18
# 21019    tt0039123            8.1       209
# 21020    tt0039125            5.1        27
# 21764    tt0040021            7.0        86
# ...            ...            ...       ...
# 1366963  tt9916708            8.6         6
# 1366965  tt9916766            7.0        22
# 1366966  tt9916778            7.2        36
# 1366967  tt9916840            8.8         6
# 1366968  tt9916880            8.2         6
#
# [766964 rows x 3 columns]

# %%
df_title_ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
df_title_crew = pd.read_csv("data/title_crew.tsv", sep='\t', low_memory=False)
df_title_crew
# Out:
#              tconst            directors  \
# 0         tt0000001            nm0005690
# 1         tt0000002            nm0721526
# 2         tt0000003            nm0721526
# 3         tt0000004            nm0721526
# 4         tt0000005            nm0005690
# ...             ...                  ...
# 10295872  tt9916848            nm1485677
# 10295873  tt9916850            nm1485677
# 10295874  tt9916852            nm1485677
# 10295875  tt9916856           nm10538645
# 10295876  tt9916880  nm0996406,nm0584014
#
#                                                     writers
# 0                                                        \N
# 1                                                        \N
# 2                                                        \N
# 3                                                        \N
# 4                                                        \N
# ...                                                     ...
# 10295872  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 10295873            nm9187127,nm1485677,nm9826385,nm1628284
# 10295874  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 10295875                                          nm6951431
# 10295876                                nm1482639,nm2586970
#
# [10295877 rows x 3 columns]

# %%
df_title_crew = df_title_crew[df_title_crew["tconst"].isin(df_title_basics['tconst'])]
df_title_crew
# Out:
#              tconst                       directors  \
# 34973     tt0035599                              \N
# 35174     tt0035803                              \N
# 37603     tt0038276             nm0626972,nm3811084
# 38437     tt0039120  nm11657766,nm0590202,nm0168641
# 38438     tt0039121                              \N
# ...             ...                             ...
# 10295871  tt9916846                       nm1485677
# 10295872  tt9916848                       nm1485677
# 10295873  tt9916850                       nm1485677
# 10295874  tt9916852                       nm1485677
# 10295876  tt9916880             nm0996406,nm0584014
#
#                                                     writers
# 34973                                                    \N
# 35174                                                    \N
# 37603                                            nm12264820
# 38437                                                    \N
# 38438                                                    \N
# ...                                                     ...
# 10295871  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 10295872  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 10295873            nm9187127,nm1485677,nm9826385,nm1628284
# 10295874  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 10295876                                nm1482639,nm2586970
#
# [8105446 rows x 3 columns]

# %%
df_title_crew['directors'].replace('\\N', np.nan, inplace=True)
# Out:
# C:\Users\Anwender\AppData\Local\Temp\ipykernel_13804\6113080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_crew['directors'].replace('\\N', np.nan, inplace=True)

# %%
df_title_crew['writers'].unique()
df_title_crew['writers'].replace('\\N', np.nan, inplace=True)
# Out:
# C:\Users\Anwender\AppData\Local\Temp\ipykernel_13804\4289790207.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_crew['writers'].replace('\\N', np.nan, inplace=True)

# %%
df_title_principals = pd.read_csv("data/title_principals.tsv", sep='\t', low_memory=False)
df_title_principals
# Out:
#              tconst  ordering     nconst         category  \
# 0         tt0000001         1  nm1588970             self
# 1         tt0000001         2  nm0005690         director
# 2         tt0000001         3  nm0374658  cinematographer
# 3         tt0000002         1  nm0721526         director
# 4         tt0000002         2  nm1335271         composer
# ...             ...       ...        ...              ...
# 58969171  tt9916880         5  nm0584014         director
# 58969172  tt9916880         6  nm0996406         director
# 58969173  tt9916880         7  nm1482639           writer
# 58969174  tt9916880         8  nm2586970           writer
# 58969175  tt9916880         9  nm1594058         producer
#
#                               job characters
# 0                              \N   ["Self"]
# 1                              \N         \N
# 2         director of photography         \N
# 3                              \N         \N
# 4                              \N         \N
# ...                           ...        ...
# 58969171                       \N         \N
# 58969172       principal director         \N
# 58969173                       \N         \N
# 58969174                    books         \N
# 58969175                 producer         \N
#
# [58969176 rows x 6 columns]

# %%
df_title_principals = df_title_principals[df_title_principals["tconst"].isin(df_title_basics['tconst'])]
df_title_principals
# Out:
#              tconst  ordering     nconst  category                 job  \
# 286977    tt0035803        10  nm0445198      self                  \N
# 286978    tt0035803         1  nm0386944      self                  \N
# 286979    tt0035803         2  nm0230638      self                  \N
# 286980    tt0035803         3  nm0246872      self                  \N
# 286981    tt0035803         4  nm0290950      self                  \N
# ...             ...       ...        ...       ...                 ...
# 58969171  tt9916880         5  nm0584014  director                  \N
# 58969172  tt9916880         6  nm0996406  director  principal director
# 58969173  tt9916880         7  nm1482639    writer                  \N
# 58969174  tt9916880         8  nm2586970    writer               books
# 58969175  tt9916880         9  nm1594058  producer            producer
#
#          characters
# 286977     ["Self"]
# 286978     ["Self"]
# 286979     ["Self"]
# 286980     ["Self"]
# 286981     ["Self"]
# ...             ...
# 58969171         \N
# 58969172         \N
# 58969173         \N
# 58969174         \N
# 58969175         \N
#
# [46014448 rows x 6 columns]

# %%
df_title_principals['job'].replace('\\N', np.nan, inplace=True)
# Out:
# C:\Users\Anwender\AppData\Local\Temp\ipykernel_13804\670053234.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_principals['job'].replace('\\N', np.nan, inplace=True)

# %%
df_title_episode = pd.read_csv("data/title_episode.tsv", sep='\t', low_memory=False)
df_title_episode
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 0        tt0041951    tt0041038            1             9
# 1        tt0042816    tt0989125            1            17
# 2        tt0042889    tt0989125           \N            \N
# 3        tt0043426    tt0040051            3            42
# 4        tt0043631    tt0989125            2            16
# ...            ...          ...          ...           ...
# 7853468  tt9916846    tt1289683            3            18
# 7853469  tt9916848    tt1289683            3            17
# 7853470  tt9916850    tt1289683            3            19
# 7853471  tt9916852    tt1289683            3            20
# 7853472  tt9916880    tt0985991            4             2
#
# [7853473 rows x 4 columns]

# %%
df_title_episode['seasonNumber'].replace('\\N', np.nan, inplace=True)
df_title_episode['seasonNumber'] = df_title_episode['seasonNumber'].astype('Int64')
df_title_episode[df_title_episode["seasonNumber"] > 1000]
# Out:
#             tconst parentTconst  seasonNumber episodeNumber
# 2016     tt0111465    tt1868747          1994            89
# 2053     tt0113395    tt1868747          1995           114
# 2691     tt0146296    tt0057775          1993             3
# 2710     tt0147908    tt1868747          1996           168
# 4091     tt0219500    tt0057775          1965             1
# ...            ...          ...           ...           ...
# 7682336  tt9479716    tt1868747          1996           160
# 7682357  tt9479762    tt1868747          1998           201
# 7686830  tt9490998    tt9139576          2018             0
# 7698875  tt9521320    tt9139576          2017             0
# 7743530  tt9637102    tt0193679          2019            20
#
# [829 rows x 4 columns]

# %%
df_title_episode['episodeNumber'].replace('\\N', np.nan, inplace=True)
df_title_episode['episodeNumber'] = df_title_episode['episodeNumber'].astype('Int64')

# %%
df_name_basics = pd.read_csv("data/name_basics.tsv", sep='\t', low_memory=False)
df_name_basics
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12991586  nm9993714   Romeo del Rosario        \N        \N
# 12991587  nm9993716       Essias Loberg        \N        \N
# 12991588  nm9993717  Harikrishnan Rajan        \N        \N
# 12991589  nm9993718         Aayush Nair        \N        \N
# 12991590  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 12991586  animation_department,art_department
# 12991587                                  NaN
# 12991588                      cinematographer
# 12991589                      cinematographer
# 12991590                                  NaN
#
#                                    knownForTitles
# 0         tt0050419,tt0045537,tt0072308,tt0053137
# 1         tt0075213,tt0037382,tt0117057,tt0038355
# 2         tt0054452,tt0056404,tt0049189,tt0057345
# 3         tt0078723,tt0080455,tt0077975,tt0072562
# 4         tt0069467,tt0050986,tt0083922,tt0050976
# ...                                           ...
# 12991586          tt14069590,tt2455546,tt11657662
# 12991587                                       \N
# 12991588                                tt8736744
# 12991589                                tt8736744
# 12991590                                       \N
#
# [12991591 rows x 6 columns]

# %%
df_name_basics.dtypes
# Out:
# nconst               object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# dtype: object

# %%
for col in ['birthYear', 'deathYear']:
    df_name_basics[col].replace('\\N', np.nan, inplace=True)
    df_name_basics[col] = df_name_basics[col].astype('Int64')
    
df_name_basics['knownForTitles'].replace('\\N', np.nan, inplace = True)

# %%
df_name_basics.dtypes
# Out:
# nconst               object
# primaryName          object
# birthYear             Int64
# deathYear             Int64
# primaryProfession    object
# knownForTitles       object
# dtype: object

# %%
title_basics = pd.merge(df_title_basics, df_title_ratings, on='tconst', how='left')
title_basics
# Out:
#             tconst  titleType                 primaryTitle  \
# 0        tt0035599   tvSeries  Voice of Firestone Televues
# 1        tt0035803   tvSeries     The German Weekly Review
# 2        tt0038276   tvSeries            You Are an Artist
# 3        tt0039120   tvSeries                    Americana
# 4        tt0039121   tvSeries               Birthday Party
# ...            ...        ...                          ...
# 8105441  tt9916846  tvEpisode                Episode #3.18
# 8105442  tt9916848  tvEpisode                Episode #3.17
# 8105443  tt9916850  tvEpisode                Episode #3.19
# 8105444  tt9916852  tvEpisode                Episode #3.20
# 8105445  tt9916880  tvEpisode    Horrid Henry Knows It All
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 0        Voice of Firestone Televues       0      1943    1947             15
# 1           Die Deutsche Wochenschau       0      1940    1945             12
# 2                  You Are an Artist       0      1946    1955             15
# 3                          Americana       0      1947    1949             30
# 4                     Birthday Party       0      1947    1949             30
# ...                              ...     ...       ...     ...            ...
# 8105441                Episode #3.18       0      2009      \N             \N
# 8105442                Episode #3.17       0      2009      \N             \N
# 8105443                Episode #3.19       0      2010      \N             \N
# 8105444                Episode #3.20       0      2010      \N             \N
# 8105445    Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres  averageRating  numVotes
# 0                                \N            NaN       NaN
# 1                  Documentary,News            8.2      58.0
# 2                         Talk-Show            NaN       NaN
# 3                  Family,Game-Show            2.7      18.0
# 4                            Family            NaN       NaN
# ...                             ...            ...       ...
# 8105441         Action,Drama,Family            NaN       NaN
# 8105442         Action,Drama,Family            NaN       NaN
# 8105443         Action,Drama,Family            NaN       NaN
# 8105444         Action,Drama,Family            NaN       NaN
# 8105445  Adventure,Animation,Comedy            8.2       6.0
#
# [8105446 rows x 11 columns]

# %%
title_basics['genres'].replace('\\N', np.nan, inplace = True)

# %%
title_basics = pd.merge(title_basics, df_title_crew, on='tconst', how='left')
title_basics
# Out:
#             tconst  titleType                 primaryTitle  \
# 0        tt0035599   tvSeries  Voice of Firestone Televues
# 1        tt0035803   tvSeries     The German Weekly Review
# 2        tt0038276   tvSeries            You Are an Artist
# 3        tt0039120   tvSeries                    Americana
# 4        tt0039121   tvSeries               Birthday Party
# ...            ...        ...                          ...
# 8105441  tt9916846  tvEpisode                Episode #3.18
# 8105442  tt9916848  tvEpisode                Episode #3.17
# 8105443  tt9916850  tvEpisode                Episode #3.19
# 8105444  tt9916852  tvEpisode                Episode #3.20
# 8105445  tt9916880  tvEpisode    Horrid Henry Knows It All
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 0        Voice of Firestone Televues       0      1943    1947             15
# 1           Die Deutsche Wochenschau       0      1940    1945             12
# 2                  You Are an Artist       0      1946    1955             15
# 3                          Americana       0      1947    1949             30
# 4                     Birthday Party       0      1947    1949             30
# ...                              ...     ...       ...     ...            ...
# 8105441                Episode #3.18       0      2009      \N             \N
# 8105442                Episode #3.17       0      2009      \N             \N
# 8105443                Episode #3.19       0      2010      \N             \N
# 8105444                Episode #3.20       0      2010      \N             \N
# 8105445    Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres  averageRating  numVotes  \
# 0                               NaN            NaN       NaN
# 1                  Documentary,News            8.2      58.0
# 2                         Talk-Show            NaN       NaN
# 3                  Family,Game-Show            2.7      18.0
# 4                            Family            NaN       NaN
# ...                             ...            ...       ...
# 8105441         Action,Drama,Family            NaN       NaN
# 8105442         Action,Drama,Family            NaN       NaN
# 8105443         Action,Drama,Family            NaN       NaN
# 8105444         Action,Drama,Family            NaN       NaN
# 8105445  Adventure,Animation,Comedy            8.2       6.0
#
#                               directors  \
# 0                                   NaN
# 1                                   NaN
# 2                   nm0626972,nm3811084
# 3        nm11657766,nm0590202,nm0168641
# 4                                   NaN
# ...                                 ...
# 8105441                       nm1485677
# 8105442                       nm1485677
# 8105443                       nm1485677
# 8105444                       nm1485677
# 8105445             nm0996406,nm0584014
#
#                                                    writers
# 0                                                      NaN
# 1                                                      NaN
# 2                                               nm12264820
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 8105441  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 8105442  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 8105443            nm9187127,nm1485677,nm9826385,nm1628284
# 8105444  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 8105445                                nm1482639,nm2586970
#
# [8105446 rows x 13 columns]

# %%
titles = title_basics[title_basics['titleType'] == 'tvSeries']
episodes = title_basics[title_basics['titleType'] == 'tvEpisode']

# %%
titles
# Out:
#             tconst titleType                  primaryTitle  \
# 0        tt0035599  tvSeries   Voice of Firestone Televues
# 1        tt0035803  tvSeries      The German Weekly Review
# 2        tt0038276  tvSeries             You Are an Artist
# 3        tt0039120  tvSeries                     Americana
# 4        tt0039121  tvSeries                Birthday Party
# ...            ...       ...                           ...
# 8105173  tt9916210  tvSeries         Rumpole of the Bailey
# 8105175  tt9916216  tvSeries  Kalyanam Mudhal Kadhal Varai
# 8105176  tt9916218  tvSeries                  Lost in Food
# 8105249  tt9916380  tvSeries           Meie aasta Aafrikas
# 8105375  tt9916678  tvSeries                    Acelerados
#
#                         originalTitle isAdult startYear endYear  \
# 0         Voice of Firestone Televues       0      1943    1947
# 1            Die Deutsche Wochenschau       0      1940    1945
# 2                   You Are an Artist       0      1946    1955
# 3                           Americana       0      1947    1949
# 4                      Birthday Party       0      1947    1949
# ...                               ...     ...       ...     ...
# 8105173         Rumpole of the Bailey       0        \N      \N
# 8105175  Kalyanam Mudhal Kadhal Varai       0      2014    2017
# 8105176                  Lost in Food       0      2016    2017
# 8105249           Meie aasta Aafrikas       0      2019      \N
# 8105375                    Acelerados       0      2019      \N
#
#         runtimeMinutes                   genres  averageRating  numVotes  \
# 0                   15                      NaN            NaN       NaN
# 1                   12         Documentary,News            8.2      58.0
# 2                   15                Talk-Show            NaN       NaN
# 3                   30         Family,Game-Show            2.7      18.0
# 4                   30                   Family            NaN       NaN
# ...                ...                      ...            ...       ...
# 8105173             \N                      NaN            NaN       NaN
# 8105175             22                  Romance            8.6      15.0
# 8105176             \N                Talk-Show            NaN       NaN
# 8105249             43  Adventure,Comedy,Family            8.3     117.0
# 8105375             \N                   Comedy            NaN       NaN
#
#                               directors              writers
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2                   nm0626972,nm3811084           nm12264820
# 3        nm11657766,nm0590202,nm0168641                  NaN
# 4                                   NaN                  NaN
# ...                                 ...                  ...
# 8105173                             NaN                  NaN
# 8105175                      nm11202129                  NaN
# 8105176                       nm0872469            nm0298279
# 8105249                       nm1857733  nm4339326,nm1859351
# 8105375   nm0042769,nm3433368,nm3855412            nm8011539
#
# [251784 rows x 13 columns]

# %%
episodes
# Out:
#             tconst  titleType                       primaryTitle  \
# 139      tt0041951  tvEpisode                     The Tenderfeet
# 244      tt0042816  tvEpisode                            Othello
# 245      tt0042889  tvEpisode  The Tragedy of King Richard II/II
# 327      tt0043426  tvEpisode                         Coriolanus
# 328      tt0043631  tvEpisode           The Life of King Henry V
# ...            ...        ...                                ...
# 8105441  tt9916846  tvEpisode                      Episode #3.18
# 8105442  tt9916848  tvEpisode                      Episode #3.17
# 8105443  tt9916850  tvEpisode                      Episode #3.19
# 8105444  tt9916852  tvEpisode                      Episode #3.20
# 8105445  tt9916880  tvEpisode          Horrid Henry Knows It All
#
#                              originalTitle isAdult startYear endYear  \
# 139                         The Tenderfeet       0      1949      \N
# 244                                Othello       0      1950      \N
# 245      The Tragedy of King Richard II/II       0      1950      \N
# 327                             Coriolanus       0      1951      \N
# 328               The Life of King Henry V       0      1951      \N
# ...                                    ...     ...       ...     ...
# 8105441                      Episode #3.18       0      2009      \N
# 8105442                      Episode #3.17       0      2009      \N
# 8105443                      Episode #3.19       0      2010      \N
# 8105444                      Episode #3.20       0      2010      \N
# 8105445          Horrid Henry Knows It All       0      2014      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes  \
# 139                 30                     Western            7.6      86.0
# 244                135                       Drama            NaN       NaN
# 245                145                       Drama            NaN       NaN
# 327                 60                       Drama            NaN       NaN
# 328                133                       Drama            NaN       NaN
# ...                ...                         ...            ...       ...
# 8105441             \N         Action,Drama,Family            NaN       NaN
# 8105442             \N         Action,Drama,Family            NaN       NaN
# 8105443             \N         Action,Drama,Family            NaN       NaN
# 8105444             \N         Action,Drama,Family            NaN       NaN
# 8105445             10  Adventure,Animation,Comedy            8.2       6.0
#
#                    directors  \
# 139                nm0782690
# 244                nm0791041
# 245                nm0605925
# 327                nm0629999
# 328                nm0107960
# ...                      ...
# 8105441            nm1485677
# 8105442            nm1485677
# 8105443            nm1485677
# 8105444            nm1485677
# 8105445  nm0996406,nm0584014
#
#                                                    writers
# 139                nm0872077,nm0289014,nm1080563,nm0834503
# 244                                              nm0000636
# 245                                    nm0000636,nm0605925
# 327                                    nm0548529,nm0000636
# 328                          nm0000636,nm0605925,nm0107960
# ...                                                    ...
# 8105441  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 8105442  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 8105443            nm9187127,nm1485677,nm9826385,nm1628284
# 8105444  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284
# 8105445                                nm1482639,nm2586970
#
# [7853662 rows x 13 columns]

# %%
episodes = pd.merge(episodes, df_title_episode, on='tconst', how='left')
episodes
# Out:
#             tconst  titleType                       primaryTitle  \
# 0        tt0041951  tvEpisode                     The Tenderfeet
# 1        tt0042816  tvEpisode                            Othello
# 2        tt0042889  tvEpisode  The Tragedy of King Richard II/II
# 3        tt0043426  tvEpisode                         Coriolanus
# 4        tt0043631  tvEpisode           The Life of King Henry V
# ...            ...        ...                                ...
# 7853657  tt9916846  tvEpisode                      Episode #3.18
# 7853658  tt9916848  tvEpisode                      Episode #3.17
# 7853659  tt9916850  tvEpisode                      Episode #3.19
# 7853660  tt9916852  tvEpisode                      Episode #3.20
# 7853661  tt9916880  tvEpisode          Horrid Henry Knows It All
#
#                              originalTitle isAdult startYear endYear  \
# 0                           The Tenderfeet       0      1949      \N
# 1                                  Othello       0      1950      \N
# 2        The Tragedy of King Richard II/II       0      1950      \N
# 3                               Coriolanus       0      1951      \N
# 4                 The Life of King Henry V       0      1951      \N
# ...                                    ...     ...       ...     ...
# 7853657                      Episode #3.18       0      2009      \N
# 7853658                      Episode #3.17       0      2009      \N
# 7853659                      Episode #3.19       0      2010      \N
# 7853660                      Episode #3.20       0      2010      \N
# 7853661          Horrid Henry Knows It All       0      2014      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes  \
# 0                   30                     Western            7.6      86.0
# 1                  135                       Drama            NaN       NaN
# 2                  145                       Drama            NaN       NaN
# 3                   60                       Drama            NaN       NaN
# 4                  133                       Drama            NaN       NaN
# ...                ...                         ...            ...       ...
# 7853657             \N         Action,Drama,Family            NaN       NaN
# 7853658             \N         Action,Drama,Family            NaN       NaN
# 7853659             \N         Action,Drama,Family            NaN       NaN
# 7853660             \N         Action,Drama,Family            NaN       NaN
# 7853661             10  Adventure,Animation,Comedy            8.2       6.0
#
#                    directors  \
# 0                  nm0782690
# 1                  nm0791041
# 2                  nm0605925
# 3                  nm0629999
# 4                  nm0107960
# ...                      ...
# 7853657            nm1485677
# 7853658            nm1485677
# 7853659            nm1485677
# 7853660            nm1485677
# 7853661  nm0996406,nm0584014
#
#                                                    writers parentTconst  \
# 0                  nm0872077,nm0289014,nm1080563,nm0834503    tt0041038
# 1                                                nm0000636    tt0989125
# 2                                      nm0000636,nm0605925    tt0989125
# 3                                      nm0548529,nm0000636    tt0040051
# 4                            nm0000636,nm0605925,nm0107960    tt0989125
# ...                                                    ...          ...
# 7853657  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284    tt1289683
# 7853658  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284    tt1289683
# 7853659            nm9187127,nm1485677,nm9826385,nm1628284    tt1289683
# 7853660  nm9187127,nm1485677,nm9826385,nm9299459,nm1628284    tt1289683
# 7853661                                nm1482639,nm2586970    tt0985991
#
#          seasonNumber  episodeNumber
# 0                   1              9
# 1                   1             17
# 2                <NA>           <NA>
# 3                   3             42
# 4                   2             16
# ...               ...            ...
# 7853657             3             18
# 7853658             3             17
# 7853659             3             19
# 7853660             3             20
# 7853661             4              2
#
# [7853662 rows x 16 columns]

# %%
df_title_principals
# Out:
#              tconst  ordering     nconst  category                 job  \
# 286977    tt0035803        10  nm0445198      self                 NaN
# 286978    tt0035803         1  nm0386944      self                 NaN
# 286979    tt0035803         2  nm0230638      self                 NaN
# 286980    tt0035803         3  nm0246872      self                 NaN
# 286981    tt0035803         4  nm0290950      self                 NaN
# ...             ...       ...        ...       ...                 ...
# 58969171  tt9916880         5  nm0584014  director                 NaN
# 58969172  tt9916880         6  nm0996406  director  principal director
# 58969173  tt9916880         7  nm1482639    writer                 NaN
# 58969174  tt9916880         8  nm2586970    writer               books
# 58969175  tt9916880         9  nm1594058  producer            producer
#
#          characters
# 286977     ["Self"]
# 286978     ["Self"]
# 286979     ["Self"]
# 286980     ["Self"]
# 286981     ["Self"]
# ...             ...
# 58969171         \N
# 58969172         \N
# 58969173         \N
# 58969174         \N
# 58969175         \N
#
# [46014448 rows x 6 columns]

# %%
df_title_principals['characters'].replace('\\N', np.nan, inplace = True)
# Out:
# C:\Users\Anwender\AppData\Local\Temp\ipykernel_13804\1546414138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_title_principals['characters'].replace('\\N', np.nan, inplace = True)

# %%
principals = df_title_principals.copy()
principals
# Out:
#              tconst  ordering     nconst  category                 job  \
# 286977    tt0035803        10  nm0445198      self                 NaN
# 286978    tt0035803         1  nm0386944      self                 NaN
# 286979    tt0035803         2  nm0230638      self                 NaN
# 286980    tt0035803         3  nm0246872      self                 NaN
# 286981    tt0035803         4  nm0290950      self                 NaN
# ...             ...       ...        ...       ...                 ...
# 58969171  tt9916880         5  nm0584014  director                 NaN
# 58969172  tt9916880         6  nm0996406  director  principal director
# 58969173  tt9916880         7  nm1482639    writer                 NaN
# 58969174  tt9916880         8  nm2586970    writer               books
# 58969175  tt9916880         9  nm1594058  producer            producer
#
#          characters
# 286977     ["Self"]
# 286978     ["Self"]
# 286979     ["Self"]
# 286980     ["Self"]
# 286981     ["Self"]
# ...             ...
# 58969171        NaN
# 58969172        NaN
# 58969173        NaN
# 58969174        NaN
# 58969175        NaN
#
# [46014448 rows x 6 columns]

# %%
names = df_name_basics.copy()
names
# Out:
#              nconst         primaryName  birthYear  deathYear  \
# 0         nm0000001        Fred Astaire       1899       1987
# 1         nm0000002       Lauren Bacall       1924       2014
# 2         nm0000003     Brigitte Bardot       1934       <NA>
# 3         nm0000004        John Belushi       1949       1982
# 4         nm0000005      Ingmar Bergman       1918       2007
# ...             ...                 ...        ...        ...
# 12991586  nm9993714   Romeo del Rosario       <NA>       <NA>
# 12991587  nm9993716       Essias Loberg       <NA>       <NA>
# 12991588  nm9993717  Harikrishnan Rajan       <NA>       <NA>
# 12991589  nm9993718         Aayush Nair       <NA>       <NA>
# 12991590  nm9993719          Andre Hill       <NA>       <NA>
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 12991586  animation_department,art_department
# 12991587                                  NaN
# 12991588                      cinematographer
# 12991589                      cinematographer
# 12991590                                  NaN
#
#                                    knownForTitles
# 0         tt0050419,tt0045537,tt0072308,tt0053137
# 1         tt0075213,tt0037382,tt0117057,tt0038355
# 2         tt0054452,tt0056404,tt0049189,tt0057345
# 3         tt0078723,tt0080455,tt0077975,tt0072562
# 4         tt0069467,tt0050986,tt0083922,tt0050976
# ...                                           ...
# 12991586          tt14069590,tt2455546,tt11657662
# 12991587                                      NaN
# 12991588                                tt8736744
# 12991589                                tt8736744
# 12991590                                      NaN
#
# [12991591 rows x 6 columns]

# %%
titles.set_index('tconst', inplace=True)
episodes.set_index('tconst', inplace=True)
principals.set_index(['tconst', 'nconst'], inplace = True)
names.set_index('nconst', inplace = True)

# %%
#storing datasets as pickle files
titles.to_pickle('data/tvseries.pkl')
episodes.to_pickle('data/episodes.pkl')
principals.to_pickle('data/principals.pkl')
names.to_pickle('data/names.pkl')
